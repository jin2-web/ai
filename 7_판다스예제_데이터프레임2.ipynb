# %% [markdown]
# <a href="https://colab.research.google.com/github/jin2-web/ai/blob/master/7_%ED%8C%90%EB%8B%A4%EC%8A%A4%EC%98%88%EC%A0%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%842.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 데이터 프레임
#   - 2차원

# %%
import pandas as pd

# %%
# 데이터 프레임 생성하기 - 방법1 리스트로
list1 = list(  [ ['한빛', '남자', '20', '180'],
 	                                   ['한결', '남자', '21', '177'],
 	                                   ['한라', '여자', '20', '160']  ] )
col_names= [  '이름', '성별', ' 나이', '키' ]
df1 = pd.DataFrame(  list1, columns = col_names )
df1

df2 = pd.DataFrame(  list1,   index=[ '1반',   '2반' , '3반'],      columns = col_names )
df2
df2.index
df2.values

# %%
#  데이터 프레임 생성하기 - 방법2 딕셔너리로
dict1 = { '이름':   {0:'한빛', 1:'한결', 2:'한라' },
              '성별':   {0:'남자', 1:'남자', 2:'여자' },
               '나이':  {0:'20', 1:'21', 2:'20' },
               '키': {0:'180', 1:'177', 2:'160' }   }
df2 = pd.DataFrame( dict1 )
df2
# Out:
#    이름  성별  나이    키
# 0  한빛  남자  20  180
# 1  한결  남자  21  177
# 2  한라  여자  20  160

# %%
#  고고림까지 딕셔너리로 만들어 데이터프레임 생성하기
dic2 = {   '이름' :  {  0: '허준호' ,  1:'이가원', 2:'배규민', 3:'고고림'    },
               '성별' :  {  0: '남자' ,  1:'여자', 2:'남자', 3:'남자'    },
               '나이' :  {  0: '30' ,  1:'24', 2:'23', 3:'21'    },
               '키' :  {  0: '183' ,  1:'162', 2:'179', 3:'182'   }
         }
df3 = pd.DataFrame( dic2 )
df3
df3.to_csv( 'df3.csv' ,  header=True, index=False, encoding= 'cp949'   )
df3.to_excel( 'df3.xlsx' ,   header=True, index=False, encoding= 'cp949'    )

# %%
# 내부df3.csv 파일 불러오기
# df4 = pd.read_csv( 'df3.csv', sep = ',' , encoding='cp949'   )

# 외부 iris.csv 파일 불러오기

# 방법1) 다운 받아서 코랩에 올려 주기

# 파일 업로드하기
#  from google.colab  import files
#  f = files.upload()
# iris_df  = pd.read_csv( 'iris.csv', sep = ',' , encoding='cp949'   )
# iris_df

# 방법2)  다운 받을 url 주소를 써주면 코랩에서 찾아서 올려 줌
iris_url = ' https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'      # Raw의 주소를 써 주세요.
iris_df  = pd.read_csv(  iris_url,  sep = ',' , encoding='cp949'   )
iris_df

# vgsales.csv 파일(비디오게임 데이터) 을 찾아서 넣기
vg_url = 'https://raw.githubusercontent.com/raghav-19/Video-Games-Sales-Data-Analysis/master/vgsales.csv'
vg_df = pd.read_csv( vg_url   )
vg_df

# %%
import pandas as pd

# %% [markdown]
# 선생님 카페 문제  파이썬 부분에 2878게시판 문제

# %%
#  데이터 프레임 만들기
# list를 이용해서 만들기
list1 = [ [ 'KFC',  1000, 4.5],
             [ 'McDonald',  2000, 3.9],
             [ 'SchoolFood',  2500, 4.2],
          ]
col_names = [ 'food', 'price', 'rating' ]
df1 = pd.DataFrame( list1, col_names )
# 딕셔너리를 이용해서 만들기
dic1 = {  'food' : { 0:'KFC', 1: 'McDonald', 2:'SchoolFood' } ,
              'price' : { 0:1000, 1: 2000, 2:2500} ,
              'rating' : { 0:4.5, 1: 3.9, 2:4.2}
          }
df2 = pd.DataFrame( dic1 )
df2
df2[ [  'food' , 'rating'  ]   ]
df2[   'food'  ]   # [   열이름 ]  결과를 시리즈로 보기
df2[   [ 'food']   ]  # [ [ 열이름 ]]  결과를 데이터프레임 보기
df2.rename( columns={ 'food' : 'place'  }, inplace=True)
df2
# Out:
#         place  price  rating
# 0         KFC   1000     4.5
# 1    McDonald   2000     3.9
# 2  SchoolFood   2500     4.2

# %% [markdown]
# 5 데이터 프레임 문제2  2879문제

# %%
data = [
    ["037730", "3R", 1510, 7.36],
    ["036360", "3SOFT", 1790, 1.65],
    ["005760", "ACTS", 1185, 1.28],
]
columns = ["종목코드", "종목명", "현재가", "등락률"]
df = pd.DataFrame(data=data, columns=columns)
df.set_index('종목코드', inplace=True)
df
# 1.  현재가가 1500 이상인 값만
df[ df['현재가']   >= 1500  ]
# 2.  현재가가 1,500원 이상이면서 1,700원 미만인 값
cond = ( df[ '현재가' ] >= 1500  )  & ( df[ '현재가' ] < 1700  )
df[  cond  ]
df
# 3. 열을 추가하기 목표가 컬럼을 추가
df['목표가'] = df['현재가'] * 0.01
df
# 4. 행을 추가
df.loc['066570'] = ['LG전자', 60000, 3.84, 60000*0.01 ]
# df.loc[인덱스번호] = ['값들 ]
df

df.loc[  '037730' ]  # '037730' 인덱스의 행의 정보를 보여준다

# 6. 컬럼명 변경 (columns 속성)
df5 = pd.DataFrame(data = [[1, 2, 3], [4, 5, 6]], columns=["A", "B", "C"])
df5
#  컬럼명을 'a', 'b', 'c'로 변경
df5.columns =  ['a', 'b', 'c' ]  # 방법1
df5
df5.rename( columns={ 'a': '가' , 'b':'나', 'c':'다'  }, inplace=True )  # 방법2
df5
# 7.
import numpy as np
data = {"카카오": [ np.nan, 221, 35], "NAVER": [52, 47, 3]}
index = [2019, 2020, 2021]
df7 = pd.DataFrame(data=data, index=index)
df7
df7.index.dtype
df7.columns.name
df7.index.name = 'year'  # 익덱스의 열들의 이름을 부여하는 것 엑셀에서 블록이름과 비슷함
df7.columns.name = 'company'
df7.index.name
df7.columns.name
df7
# 8.
data = {"카카오": [np.nan, 221, 35], "NAVER": [52, 47, 3]}
index = [2019, 2020, 2021]
df8 = pd.DataFrame(data=data, index=index)
df8

# 9. 데이터프레임 drop  '카카오'와 'NAVER' 컬럼을 삭제
df8.drop( '카카오', axis= 1  )
df8.drop( 'NAVER', axis= 1  )
df8.drop(  [ '카카오', 'NAVER' ]  , axis=1)
# 10
data = [
    [1, 2, 3],
    [np.nan, 5, 6],
    [7, np.nan, 9],
    [10, 11, np.nan]
]
df10 = pd.DataFrame(data)
df10
# np.nan 값이 있는 모든 행을 제거
df10.dropna()

# 11
data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df11 = pd.DataFrame(data, columns=columns)
df11
# 문제  col2 컬럼의 값에 NaN이 포함된 행만 제거
df11.dropna( subset = 'col2' )
# 12   NaN 값을 0으로 채우기
df12 = df11.fillna( 0 )
# 13 replace  0을 100으로 변경
df12.replace( 0, 100  )

# 14
data = [
    {"cd":"A060310", "nm":"3S", "open":2920, "close":2800},
    {"cd":"A095570", "nm":"AJ네트웍스", "open":1920, "close":1900},
    {"cd":"A006840", "nm":"AK홀딩스", "open":2020, "close":2010},
    {"cd":"A054620", "nm":"APS홀딩스", "open":3120, "close":3200}
]
df14 = pd.DataFrame(data=data)
df14 = df14.set_index('cd')
df14
# 종가(close)가 시가(open)보다 큰 데이터만 가져오기
df14.query( 'open  <  close '   )
# 15  종가(close)가 3,000원 이상인 종목만 출력
df14.query( 'close >= 3000' )
# 16  시가(open)가 2,000원 이상이고 종가(close)가 시가(open)이상인 종목
df14.query( 'open >=2000 and close >= open')
# 17.  종목명(nm)이 'A'로 시작하는 종목만 ??
# cond=df14[ 'nm'].str[ :1 ]
df14.query(     "nm.str.startswith('A')"   )
# 18. 종목명에 '홀딩스'가 포함된 종목만
df14.query( "nm.str.contains('홀딩스')" )
# 19.
data = {
    "PER": [6.42, 17.63, 21.09, 13.93],
    "PBR": [1.10, 1.49, 2.06, 1.88],
    "DPS": [1416, 1716, 2994, 1755]
}
index = ["2019/12", "2020/12", "2021/12", "2022/12(E)"]
df19 = pd.DataFrame(data=data, index=index)
# df19[ ['PER', 'PBR'] ]
#  20 PER'과 'PBR' 컬럼을 선택
df19.filter( items=[  'PER', 'PBR' ] , axis=1 )
# 21 filter 메서드를 사용해서 예상치인 '2022/12(E)'를 제외한 나머지 로우 데이터를 선택
df19.filter(  regex='12$', axis=0  )
# 22  "2022"년 데이터만 선택
df19.filter(  like='2022', axis = 0 )
# Out:
#               PER   PBR   DPS
# 2022/12(E)  13.93  1.88  1755

# %% [markdown]
# 데이터프레임 문제3  카페에서 2880 번호 문제

# %%
from datetime import datetime
import numpy as np
import pandas as pd

# %%
columns = ['open', 'high', 'low', 'close']
index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

index2 = [
    datetime(2022, 9, 1),
    datetime(2022, 8, 31),
    datetime(2022, 8, 30),
    datetime(2022, 8, 29),
    datetime(2022, 8, 26)
]

df1 = pd.DataFrame(data=np.arange(0, 20).reshape(5,4), index=index1, columns=columns)
df2 = pd.DataFrame(data=np.arange(20,40).reshape(5,4), index=index2, columns=columns)
df1
df2
# 1. 위/아래 방향으로 연결하세요
pd.concat( [ df1, df2 ], axis = 0 )
#. 2. df2 df1
pd.concat( [ df2, df1 ], axis=0 )
# 3. 좌우로 붙이고
pd.concat( [ df1, df2],  axis=1 ) # full outter join이 됨

index = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

df1 = pd.DataFrame(data=np.arange(0, 10).reshape(5,2), index=index, columns=['open', 'high'])
df2 = pd.DataFrame(data=np.arange(10,20).reshape(5,2), index=index, columns=['low', 'close'])
pd.concat( [ df1, df2] , axis=1 )

# 4.
index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7)
]

index2 = [
    datetime(2022, 9, 6),
    datetime(2022, 9, 5)
]
df1 = pd.DataFrame(np.arange(0, 6).reshape(2,3), index=index1, columns=['open', 'high', 'low'])
df2 = pd.DataFrame(np.arange(6,12).reshape(2,3), index=index2, columns=['high', 'low', 'close'])
pd.concat( [df1, df2], join='outer' )
# 6
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])
pd.concat( [ s1, s2 ] )
# 7
pd.concat( [ s1, s2 ] , axis=1 )
# 8
df1 = pd.DataFrame(np.arange(0, 4).reshape(2,2))
df2 = pd.DataFrame(np.arange(4, 8).reshape(2,2))
pd.concat( [ df1, df2] , ignore_index=True )

# 9
data = [
    ["2차전지(생산)", "SK이노베이션", 10.19, 1.29],
    ["해운", "팬오션", 21.23, 0.95],
    ["시스템반도체", "티엘아이", 35.97, 1.12],
    ["해운", "HMM", 21.52, 3.20],
    ["시스템반도체", "아이에이", 37.32, 3.55],
    ["2차전지(생산)", "LG화학", 83.06, 3.75]
]

columns = ["테마", "종목명", "PER", "PBR"]
df9 = pd.DataFrame(data=data, columns=columns)
df9.groupby(  by='테마' ).mean()  # 9
df9.groupby(  by='테마' ).max()  # 10
df9.groupby(  by='테마' ).min()  # 10
df9.groupby(  by='테마' ).size()  #  11
# '테마' 컬럼으로 그룹핑한 후 '2차전지(생산)' 그룹만
gb1 = df9.groupby( by='테마')
gb1.get_group(  '2차전지(생산)'  )
# 13. 테마별 PER의 평균을
df9.groupby(  by='테마' ).mean()[ [ 'PER' ] ]
# 14. 테마로 그룹화한 후 PER, PBR 컬럼을 슬라이싱
# 시스템반도체 행만 보이기
df9_g = df9.groupby(  by='테마' ).mean()
df9_g.loc[ [   '시스템반도체'   ]   ]
# 15. DataFrame.groupby agg  max 함수
df9.groupby( by='테마').agg(  max  )
# 16.  PER 컬럼은 max, PBR 컬럼은 min 함수
df9.groupby( by='테마').agg(  { 'PER': max , 'PBR' : min }  )
#17 *****  많이 쓰는 코드
for name, group in df9.groupby("테마"):
    print(name)
    print(group)
# 18   '테마' 컬럼으로 그룹화한 후 PER, PBR 컬럼에 np.mean과 np.std 함수를 적용
df9.groupby( by='테마')[[ 'PER', 'PBR' ]].agg( [ np.mean, np.std  ])
# 19.   데이터의 빈도수
df9.groupby( by='테마')['종목명'].nunique()
# Out:
# 2차전지(생산)
#          테마      종목명    PER   PBR
# 0  2차전지(생산)  SK이노베이션  10.19  1.29
# 5  2차전지(생산)     LG화학  83.06  3.75
# 시스템반도체
#        테마   종목명    PER   PBR
# 2  시스템반도체  티엘아이  35.97  1.12
# 4  시스템반도체  아이에이  37.32  3.55
# 해운
#    테마  종목명    PER   PBR
# 1  해운  팬오션  21.23  0.95
# 3  해운  HMM  21.52  3.20
# <ipython-input-57-fd891f0c5be3>:77: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(  by='테마' ).mean()  # 9
# <ipython-input-57-fd891f0c5be3>:85: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(  by='테마' ).mean()[ [ 'PER' ] ]
# <ipython-input-57-fd891f0c5be3>:88: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9_g = df9.groupby(  by='테마' ).mean()
# 테마
# 2차전지(생산)    2
# 시스템반도체      2
# 해운          2
# Name: 종목명, dtype: int64

# %% [markdown]
# # group by 문제 추가

# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset( 'titanic' )
df.head()

# %% [markdown]
# 컬럼(columns) 설명
#
# survivied: 생존여부 (1: 생존, 0: 사망)
#
# pclass: 좌석 등급 (1등급, 2등급, 3등급)
#
# sex: 성별
#
# age: 나이
#
# sibsp: 형제 + 배우자 수
#
# parch: 부모 + 자녀 수
#
# fare: 좌석 요금
#
# embarked: 탑승 항구 (S, C, Q)
#
# class: pclass와 동일
#
# who: 남자(man), 여자(woman), 아이(child)
#
# adult_male: 성인 남자 여부
#
# deck: 데크 번호 (알파벳 + 숫자 혼용)
#
# embark_town: 탑승 항구 이름
#
# alive: 생존여부 (yes, no)
#
# alone: 혼자 탑승 여부

# %%
df.head()
df[ 'who' ].value_counts()
# 사용자 함수 만들기
def  transform_who( x )  :
    if x == 'man' :
        return '남자'
    elif x=='woman':
        return '여자'
    else:
        return '아이'
df['who'].apply(  transform_who  )  # 사용자가 정의한 함수를 호출해주기 apply( 사용자함수명 )
df['who'].apply(  transform_who  ).value_counts()

# 좌석요금 :fare
# 나이 : age
# 구하려는 값은 fare / age
def  tr_fare_age( x  ) :
    return x['fare'] / x['age']
df.apply( tr_fare_age, axis=1 )
df.head() # 7.25 / 22.0  = 0.329

# 문제 타이타닉 호의 생존자(survived =1) 와 사망자(survived=0) 를 성별(sex) 기준으로 그룹핑하여 평균을 살펴보기
df.groupby(  by='sex' ).mean()

# 문제  성별(sex), 좌석등급(pclass) 별 통계 평균구하기
df.groupby( [  'sex',   'pclass'    ]).mean()
df.groupby( [   'pclass' ,  'sex'    ]).mean()

# 문제 성별(sex), 좌석등급(pclass) 별  통계 평균구하기  survived열만 보기
df.groupby( [  'sex',   'pclass'    ]).mean()[ [  'survived' ] ]
df.groupby( [  'sex',   'pclass'    ])[ [  'survived' ] ].mean()  # 필요한 컬럼만 추출한 후 계산  잘 짠 코드

# 출력의 모습 바꾸기 인덱스 번호을 다시 0번부터 붙여 주어서 표(데이터 프레임) 처럼  만들어 보기
df.groupby( [ 'sex', 'pclass' ]  )[[ 'survived']].mean().reset_index()

#  생존율 평균구하고 나이 합계구하기
# df.groupby( [ 'sex', 'pclass' ]  ).agg(  { 'survived': mean, 'age' : sum})   #agg(  { 'PER': max , 'PBR' : min }  )
df.groupby(['sex', 'pclass'])[['survived', 'age']].agg(['mean', 'sum'])
# Out:
# <ipython-input-80-136bf2f36430>:23: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(  by='sex' ).mean()
# <ipython-input-80-136bf2f36430>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby( [  'sex',   'pclass'    ]).mean()
# <ipython-input-80-136bf2f36430>:27: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby( [   'pclass' ,  'sex'    ]).mean()
# <ipython-input-80-136bf2f36430>:30: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby( [  'sex',   'pclass'    ]).mean()[ [  'survived' ] ]
#                survived            age
#                    mean sum       mean      sum
# sex    pclass
# female 1       0.968085  91  34.611765  2942.00
#        2       0.921053  70  28.722973  2125.50
#        3       0.500000  72  21.750000  2218.50
# male   1       0.368852  45  41.281386  4169.42
#        2       0.157407  17  30.740707  3043.33
#        3       0.135447  47  26.507589  6706.42

# %% [markdown]
# 데이터프레임 문제4  선생님 카페(2881)  문제

# %%
data = [
    ['Multiples', 'PER', 21.09, 13.55],
    ['Multiples', 'PBR', 2.06, 1.80],
    ['Dividends', 'DPS', 2944, 1444],
    ['Dividends', '배당성향', 78, 25]
]
columns = ['Category', 'Factor', 2020, 2021]
df = pd.DataFrame(data, columns=columns)
df
# # 2 멀티 인덱스 - 열이름으로 인덱스
df = df.set_index( [ 'Category', 'Factor'  ])
df
# 3
# tuples = [
#     ('Multiples', 'PER'),
#     ('Multiples', 'PBR'),
#     ('Dividends', 'DPS'),
#     ('Dividends', '배당성향')
# ]
# index = pd.MultiIndex.from_tuples( tuples, names=[ 'Category', 'Factor'  ] )
# df
# # 4
arrays = [
    ['Mutiples', 'Multiples', 'Dividends', 'Dividends'],
    ['PER', 'PBR', 'DPS', '배당성향']
]
index = pd.MultiIndex.from_arrays(  arrays,  names=[ 'Category', 'Factor'  ]  )
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
# 5
tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]


data = [
    [21.09, 13.55],
    [2.06, 1.80],
    [2944, 1444],
    [78, 25]
]

columns = [2020, 2021]
df

# 6
df.loc[ 'Multiples']
# 7  Multiples의 PER 로우만
df.loc[  (   'Multiples', 'PER'   )      ]
# 8  Multiples의 PER 로우만
df.iloc[   2  ]  # 0번 인덱스
# 9 loc 속성을 사용하여 2020년 PER 값을 출력
df.loc[   (   'Multiples', 'PER'),    2020  ]
# 10
df.sort_index()

# %% [markdown]
# 5 데이터 프레임 응용문제1 - 붓꽃데이터

# %%
iris_url = ' https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'      # Raw의 주소를 써 주세요.
iris_df  = pd.read_csv(  iris_url,  sep = ',',    encoding='cp949'   )
iris_df.head()
list_index = np.arange(1, 150)
df = pd.DataFrame( iris_df,  index = list_index )
# 인덱스 이름 넣기
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-09aa27bc83ae> in <cell line: 7>()
#       5 df = pd.DataFrame( iris_df,  index = list_index )
#       6 # 인덱스 이름 넣기
# ----> 7 df.rename( index = 'Id' )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5571         4  3  6
#    5572         """
# -> 5573         return super()._rename(
#    5574             mapper=mapper,
#    5575             index=index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1092                     indexer = ax.get_level_values(level).get_indexer_for(replacements)
#    1093                 else:
# -> 1094                     indexer = ax.get_indexer_for(replacements)
#    1095
#    1096                 if errors == "raise" and len(indexer[indexer == -1]):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer_for(self, target)
#    6050         """
#    6051         if self._index_as_unique:
# -> 6052             return self.get_indexer(target)
#    6053         indexer, _ = self.get_indexer_non_unique(target)
#    6054         return indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3897         method = missing.clean_reindex_fill_method(method)
#    3898         orig_target = target
# -> 3899         target = self._maybe_cast_listlike_indexer(target)
#    3900
#    3901         self._check_indexing_method(method, limit, tolerance)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _maybe_cast_listlike_indexer(self, target)
#    6578         Analogue to maybe_cast_indexer for get_indexer instead of get_loc.
#    6579         """
# -> 6580         return ensure_index(target)
#    6581
#    6582     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    7331             return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7332     else:
# -> 7333         return Index._with_infer(index_like, copy=copy)
#    7334
#    7335
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _with_infer(cls, *args, **kwargs)
#     714         with warnings.catch_warnings():
#     715             warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 716             result = cls(*args, **kwargs)
#     717
#     718         if result.dtype == _dtype_obj and not result._is_multi:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     543
#     544         elif is_scalar(data):
# --> 545             raise cls._scalar_data_error(data)
#     546         elif hasattr(data, "__array__"):
#     547             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'Id' was passed
